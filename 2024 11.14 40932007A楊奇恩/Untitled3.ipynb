# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 10, 100)   # 產生 0～10 總共 100 連續數字
y = 4 + 2 * np.sin(2 * x)     # 使用 NumPy 的廣播方式，產生sin 數值的陣列y
fig, ax = plt.subplots()
ax.plot(x, y, linewidth=2.0)  # 繪製折線圖
ax.set(xlim=(0, 8), xticks=np.arange(1, 8),  # 設定座標軸
ylim=(0, 8), yticks=np.arange(1, 8))
plt.show()    # 顯示圖表

# %% [markdown]
# 作業2

# %%
import numpy as np
import pandas as pd
dates = pd.date_range("20130101", periods=100)
df = pd.DataFrame(np.random.randn(100, 4), index=dates,
columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.572746  1.008096  0.617121  0.389685
# 2013-01-02  1.525394 -1.293346 -0.852583 -0.955600
# 2013-01-03  0.650565  1.331300  0.923008 -1.146906
# 2013-01-04 -1.104762 -2.256564 -0.634487 -0.211040
# 2013-01-05 -0.243514 -0.184208  0.703881 -0.549079
# ...              ...       ...       ...       ...
# 2013-04-06  0.258680 -3.236778  0.047485  0.722895
# 2013-04-07 -0.097393  0.699111 -0.045680 -0.939458
# 2013-04-08  1.126471  0.374569 -1.470712  0.890269
# 2013-04-09 -0.366250  0.894181  0.210780  0.925296
# 2013-04-10  1.031774  1.080537  0.246976 -0.910636
#
# [100 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
x = df
#請問這裡要怎麼改?
 # 畫出顏色紅色、圓形錨點、虛線、粗細2、資料點大小6 的線條
#plt.plot(x,color='r', marker='o', linewidth=2, markersize=6)

# 繪製圖表
plt.plot(x['A'], color='r', marker='o', linestyle='--', linewidth=2, markersize=6, label='A')
plt.plot(x['B'], color='b', marker='o', linestyle='--', linewidth=2, markersize=6, label='B')
plt.plot(x['C'], color='g', marker='o', linestyle='--', linewidth=2, markersize=6, label='C')
plt.plot(x['D'], color='purple', marker='o', linestyle='--', linewidth=2, markersize=6, label='D')

# 添加圖例
plt.legend()

 #plt.plot(x)
plt.show()

# %%
import matplotlib.pyplot as plt
x = df
#請問這裡要怎麼改?
 # 畫出顏色紅色、圓形錨點、虛線、粗細2、資料點大小6 的線條
#plt.plot(x,color='r', marker='o', linewidth=2, markersize=6)

# 繪製圖表
plt.plot(x['A'], color='r', marker='o', linestyle='--', linewidth=2, markersize=6, label='A')
# 添加圖例
plt.legend()
#plt.plot(x)
plt.show()
# 繪製圖表
plt.plot(x['B'], color='b', marker='o', linestyle='--', linewidth=2, markersize=6, label='B')
# 添加圖例
plt.legend()
#plt.plot(x)
plt.show()
# 繪製圖表
plt.plot(x['C'], color='g', marker='o', linestyle='--', linewidth=2, markersize=6, label='C')
plt.legend()
#plt.plot(x)
plt.show()
# 繪製圖表
plt.plot(x['D'], color='purple', marker='o', linestyle='--', linewidth=2, markersize=6, label='D')

plt.legend()



 #plt.plot(x)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generate the DataFrame
dates = pd.date_range("20130101", periods=100)
df = pd.DataFrame(np.random.randn(100, 4), index=dates, columns=list("ABCD"))

# Calculate the mean for each column
df_mean = df.mean()

# Combined bar chart for all columns
plt.figure(figsize=(8, 6))
df_mean.plot(kind='bar', color=['red', 'blue', 'green', 'purple'], alpha=0.7)
plt.title("Mean Values of Columns A, B, C, D")
plt.ylabel("Mean Value")
plt.xlabel("Columns")
plt.show()

# Combined pie chart for all columns
plt.figure(figsize=(8, 6))
df_mean_abs = df_mean.abs()  # Use absolute mean values for pie chart
df_mean_abs.plot(kind='pie', autopct='%1.1f%%', colors=['red', 'blue', 'green', 'purple'], startangle=90)
plt.title("Proportion of Mean Values in Columns A, B, C, D")
plt.ylabel("")
plt.show()

# Combined 3D bar chart for all columns
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
x_pos = np.arange(len(df_mean))
y_pos = [0] * len(df_mean)  # Fixed y position for all bars
z_pos = [0] * len(df_mean)  # Fixed z position for all bars
dx = dy = 0.5
dz = df_mean.values

ax.bar3d(x_pos, y_pos, z_pos, dx, dy, dz, color=['red', 'blue', 'green', 'purple'], alpha=0.7)
ax.set_xlabel("Columns")
ax.set_ylabel("Y-Axis (fixed)")
ax.set_zlabel("Mean Value")
ax.set_xticks(x_pos)
ax.set_xticklabels(df_mean.index)
ax.set_title("3D Bar Chart of Mean Values for Columns A, B, C, D")
plt.show()
