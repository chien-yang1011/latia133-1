# %%
    import pandas as pd
    import numpy as np_

# %%
 df=pd.read_parquet('A_stat_data_112.parquet')

# %%
df2=df.copy()
df2.head(100)
df2.head(1000).to_csv('the_table_that_I_look.csv')

# %%
a=df2.columns
a_series=a.to_series()
print(a_series)
a_series.to_csv('work.csv',index=False)
# Out:
# grade                                                                  grade
# mission_name                                                    mission_name
# mission_difficulty                                        mission_difficulty
# mission_field                                                  mission_field
# mission_type                                                    mission_type
# mission_semester_year                                  mission_semester_year
# mission_semester                                            mission_semester
# mission_datetime_utc8                                  mission_datetime_utc8
# mission_status                                                mission_status
# is_completed                                                    is_completed
# completed_at_utc8                                          completed_at_utc8
# correct_rate                                                    correct_rate
# ...

# %%
df.describe()
# Out:
#        mission_semester_year       mission_datetime_utc8  is_completed  \
# count              1909959.0                     1909959     1909959.0
# mean                   112.0  2024-01-26 02:55:57.401912      0.238161
# min                    112.0         2023-08-31 08:00:00           0.0
# 25%                    112.0         2023-11-02 08:00:00           0.0
# 50%                    112.0         2024-01-11 08:00:00           0.0
# 75%                    112.0         2024-04-18 08:00:00           0.0
# max                    112.0         2024-06-27 08:00:00           1.0
# std                      0.0                         NaN      0.425958
#
#                 completed_at_utc8   correct_rate  answer_duration_sec  \
# count                      453866  454877.000000             453620.0
# mean   2024-02-11 06:34:43.966656       0.412165           147.150187
# min           2023-08-31 08:25:39       0.000000                  1.0
# ...

# %%
a = df["mission_semester_year"]
a.to_csv('kk.csv',index=False)

# %%
a_series.to_csv('kk.csv',index=False)
